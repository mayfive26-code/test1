# %%
def main():
    print("我是專案檔的主執行檔")
    
if __name__ == "__main__":
    main()
# Out:
# 我是專案檔的主執行檔

# %%
import playwright
playwright.sync_api.sync_playwright
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import playwright
# ----> 2 playwright.sync_api.sync_playwright
#
# AttributeError: module 'playwright' has no attribute 'sync_api'

# %%
import playwright
from playwright import sync_api
sync_api.sync_playwright()

# %%
from playwright.sync_api import sync_playwright

sync_playwright()
#此版本較好

# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045
